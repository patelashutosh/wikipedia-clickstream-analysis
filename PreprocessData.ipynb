# %%
# !pip install wikipedia-api
# !pip install spacy
# !pip install en_core_web_sm
# !python -m spacy download en_core_web_sm
# Out:
# Requirement already satisfied: wikipedia-api in /opt/conda/lib/python3.8/site-packages (0.5.4)
# Requirement already satisfied: requests in /opt/conda/lib/python3.8/site-packages (from wikipedia-api) (2.25.1)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests->wikipedia-api) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests->wikipedia-api) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests->wikipedia-api) (2.10)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests->wikipedia-api) (1.26.3)
# Requirement already satisfied: spacy in /opt/conda/lib/python3.8/site-packages (3.1.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from spacy) (2.0.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /opt/conda/lib/python3.8/site-packages (from spacy) (2.0.6)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /opt/conda/lib/python3.8/site-packages (from spacy) (0.3.2)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.8/site-packages (from spacy) (2.25.1)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /opt/conda/lib/python3.8/site-packages (from spacy) (0.8.2)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.8/site-packages (from spacy) (1.20.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.8/site-packages (from spacy) (4.57.0)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.8/site-packages (from spacy) (2.11.3)
# Requirement already satisfied: pathy>=0.3.5 in /opt/conda/lib/python3.8/site-packages (from spacy) (0.6.0)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /opt/conda/lib/python3.8/site-packages (from spacy) (0.7.4)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from spacy) (49.6.0.post20210108)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.8/site-packages (from spacy) (20.9)
# Requirement already satisfied: thinc<8.1.0,>=8.0.8 in /opt/conda/lib/python3.8/site-packages (from spacy) (8.0.10)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.8/site-packages (from spacy) (1.0.5)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /opt/conda/lib/python3.8/site-packages (from spacy) (2.4.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from spacy) (3.0.5)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in /opt/conda/lib/python3.8/site-packages (from spacy) (3.0.8)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /opt/conda/lib/python3.8/site-packages (from spacy) (1.8.2)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from packaging>=20.0->spacy) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /opt/conda/lib/python3.8/site-packages (from pathy>=0.3.5->spacy) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy) (3.7.4.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (1.26.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2020.12.5)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (4.0.0)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy) (2.10)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /opt/conda/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.8/site-packages (from jinja2->spacy) (1.1.1)
# Requirement already satisfied: en_core_web_sm in /opt/conda/lib/python3.8/site-packages (3.1.0)
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in /opt/conda/lib/python3.8/site-packages (from en_core_web_sm) (3.1.2)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en_core_web_sm) (2.11.3)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en_core_web_sm) (0.8.2)
# Requirement already satisfied: thinc<8.1.0,>=8.0.8 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en_core_web_sm) (8.0.10)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en_core_web_sm) (4.57.0)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en_core_web_sm) (20.9)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en_core_web_sm) (2.25.1)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en_core_web_sm) (3.0.5)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en_core_web_sm) (2.0.6)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en_core_web_sm) (0.7.4)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en_core_web_sm) (3.0.8)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en_core_web_sm) (0.3.2)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en_core_web_sm) (2.0.5)
# Requirement already satisfied: pathy>=0.3.5 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en_core_web_sm) (0.6.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en_core_web_sm) (2.4.1)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en_core_web_sm) (1.20.1)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en_core_web_sm) (1.8.2)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en_core_web_sm) (49.6.0.post20210108)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en_core_web_sm) (1.0.5)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->en_core_web_sm) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /opt/conda/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->en_core_web_sm) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.2.0,>=3.1.0->en_core_web_sm) (3.7.4.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en_core_web_sm) (1.26.3)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en_core_web_sm) (4.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en_core_web_sm) (2020.12.5)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en_core_web_sm) (2.10)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /opt/conda/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.2.0,>=3.1.0->en_core_web_sm) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.8/site-packages (from jinja2->spacy<3.2.0,>=3.1.0->en_core_web_sm) (1.1.1)
# Collecting en-core-web-sm==3.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.1.0/en_core_web_sm-3.1.0-py3-none-any.whl (13.6 MB)
#      |████████████████████████████████| 13.6 MB 2.9 MB/s eta 0:00:01    |███▎                            | 1.4 MB 1.4 MB/s eta 0:00:09     |█████████████▉                  | 5.9 MB 2.7 MB/s eta 0:00:03     |█████████████████▉              | 7.6 MB 2.7 MB/s eta 0:00:03     |███████████████████▉            | 8.4 MB 2.7 MB/s eta 0:00:02     |████████████████████████▍       | 10.4 MB 2.3 MB/s eta 0:00:02
# Requirement already satisfied: spacy<3.2.0,>=3.1.0 in /opt/conda/lib/python3.8/site-packages (from en-core-web-sm==3.1.0) (3.1.2)
# Requirement already satisfied: typer<0.4.0,>=0.3.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.3.2)
# Requirement already satisfied: pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.8.2)
# Requirement already satisfied: wasabi<1.1.0,>=0.8.1 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.8.2)
# Requirement already satisfied: catalogue<2.1.0,>=2.0.4 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.25.1)
# Requirement already satisfied: pathy>=0.3.5 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.6.0)
# Requirement already satisfied: srsly<3.0.0,>=2.4.1 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.11.3)
# Requirement already satisfied: spacy-legacy<3.1.0,>=3.0.7 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.8)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (20.9)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.0.5)
# Requirement already satisfied: thinc<8.1.0,>=8.0.8 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (8.0.10)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.0.5)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.57.0)
# Requirement already satisfied: numpy>=1.15.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.20.1)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.0.5)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (49.6.0.post20210108)
# Requirement already satisfied: blis<0.8.0,>=0.4.0 in /opt/conda/lib/python3.8/site-packages (from spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (0.7.4)
# Requirement already satisfied: pyparsing>=2.0.2 in /opt/conda/lib/python3.8/site-packages (from packaging>=20.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.4.7)
# Requirement already satisfied: smart-open<6.0.0,>=5.0.0 in /opt/conda/lib/python3.8/site-packages (from pathy>=0.3.5->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (5.2.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.8/site-packages (from pydantic!=1.8,!=1.8.1,<1.9.0,>=1.7.4->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (3.7.4.3)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2020.12.5)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.26.3)
# Requirement already satisfied: idna<3,>=2.5 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (2.10)
# Requirement already satisfied: chardet<5,>=3.0.2 in /opt/conda/lib/python3.8/site-packages (from requests<3.0.0,>=2.13.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (4.0.0)
# Requirement already satisfied: click<7.2.0,>=7.1.1 in /opt/conda/lib/python3.8/site-packages (from typer<0.4.0,>=0.3.0->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (7.1.2)
# Requirement already satisfied: MarkupSafe>=0.23 in /opt/conda/lib/python3.8/site-packages (from jinja2->spacy<3.2.0,>=3.1.0->en-core-web-sm==3.1.0) (1.1.1)
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')

# %%
# !pip install kafka
# Out:
# Requirement already satisfied: kafka in /opt/conda/lib/python3.8/site-packages (1.3.5)

# %%
import wikipediaapi

# %%
import spacy
from spacy import displacy
from collections import Counter
import en_core_web_sm
nlp = en_core_web_sm.load()

# %%
import csv
from random import randrange
from datetime import timedelta
from datetime import datetime
from time import sleep
from json import dumps
#from kafka import KafkaProducer
from collections import defaultdict
import os

# %%
#Need to update date for different month / year

start_date = datetime.strptime("1/1/2018 1:30 PM", "%m/%d/%Y %I:%M %p")
end_date = datetime.strptime("1/1/2019 4:50 AM", "%m/%d/%Y %I:%M %p")
delta = end_date - start_date
int_delta = (delta.days * 24 * 60 * 60) + delta.seconds

# %%
def getPageCategory(pageName):
    wiki_wiki = wikipediaapi.Wikipedia('en')
    page_py = wiki_wiki.page(pageName)
    cat1 = str(page_py.categories)
    doc = nlp(cat1)
    temp = defaultdict(int)
    for i in doc.ents:
        if not str(i).isnumeric() and str(i)!='Wikipedia':
            temp[i] += 1
    res = max(temp, key=temp.get)
    return str(res)
#print("Word with maximum frequency : " + str(res))
    
#print(doc.ents)
#sorted(page_py.categories)
#cat1

# %%
#with open("data2.tsv") as file:
def processFile(file):
    tsv_file = csv.reader(file, delimiter="\t")
    for line in tsv_file:
        set_category = getPageCategory(line[1])
        for i in range(int(line[3])):
            random_second = randrange(int_delta)
            set_date = start_date + timedelta(seconds=random_second)
            #print(line[0]+" "+line[1]+" "+line[2] + " " + str(set_date) +" "+ str(set_category))
            data = line[0]+" "+line[1]+" "+line[2] + " " + str(set_date)+" "+str(set_category)
            #producer.send('topic_1', value=data)
        #sleep(0.5)
        print(line[0]+" "+line[1]+" "+line[2] +" "+ str(set_category))

# %%
folderpath = r"./split/" # make sure to put the 'r' in front
filepaths  = [os.path.join(folderpath, name) for name in os.listdir(folderpath)]

for path in filepaths:
    #os.path.basename(filepath)
    with open(path, 'r') as f:
        processFile(f)
# Out:
# other-search Scharnegoutum external West Frisian-language
# Drew_Dober UFC_Fight_Night:_Muñoz_vs._Mousasi link German
# List_of_UFC_events UFC_Fight_Night:_Muñoz_vs._Mousasi link German
# other-empty UFC_Fight_Night:_Muñoz_vs._Mousasi external German
# The_Ultimate_Fighter:_Brazil_3 UFC_Fight_Night:_Muñoz_vs._Mousasi link German
# Sean_Strickland UFC_Fight_Night:_Muñoz_vs._Mousasi link German
# C._B._Dollaway UFC_Fight_Night:_Muñoz_vs._Mousasi link German
# Mark_Muñoz UFC_Fight_Night:_Muñoz_vs._Mousasi link German
# UFC_173 UFC_Fight_Night:_Muñoz_vs._Mousasi link German
# Nick_Hein UFC_Fight_Night:_Muñoz_vs._Mousasi link German
# Francis_Carmont UFC_Fight_Night:_Muñoz_vs._Mousasi link German
# Gegard_Mousasi UFC_Fight_Night:_Muñoz_vs._Mousasi link German
# other-search UFC_Fight_Night:_Muñoz_vs._Mousasi external German
# Krzysztof_Jotko UFC_Fight_Night:_Muñoz_vs._Mousasi link German
# other-empty Thamudic_B external North Arabian'
# other-search Thamudic_B external North Arabian'
# Thamudic Thamudic_B link North Arabian'
# other-search Israel_Hajaj external Netanya
# List_of_web_browsers AT&T_Pogo link AT&T
# other-empty AT&T_Pogo external AT&T
# HTTP_cookie AT&T_Pogo link AT&T
# other-external AT&T_Pogo external AT&T
# other-empty Sokari_Douglas_Camp external Category:20th-century
# African_immigration_to_Europe Sokari_Douglas_Camp link Category:20th-century
# other-search Sokari_Douglas_Camp external Category:20th-century
# other-external Sokari_Douglas_Camp external Category:20th-century
# other-empty NoitulovE external British
# other-internal NoitulovE external British
# Good_things_come_to_those_who_wait_(Guinness) NoitulovE link British
# other-search NoitulovE external British
# other-search Sahara_and_Sahel_Observatory external French
# other-empty İnegöl_meatballs external April 2015'
# Meatball İnegöl_meatballs link April 2015'
# Kofta İnegöl_meatballs link April 2015'
# other-search İnegöl_meatballs external April 2015'
# other-empty Prison_on_Łącki_Street external Ukraine
# Lviv_pogroms_(1941) Prison_on_Łącki_Street link Ukraine
# other-search Prison_on_Łącki_Street external Ukraine
# Hugh_Walters_(author) The_Domes_of_Pico link British
# other-empty Frank_Steglich external Category:20th-century
# other-search Frank_Steglich external Category:20th-century
# Miss_Universe_2001 Malin_Olsson link Category:21st-century
# other-empty Malin_Olsson external Category:21st-century
# other-internal Malin_Olsson external Category:21st-century
# other-search Malin_Olsson external Category:21st-century
# Miss_Sweden Malin_Olsson link Category:21st-century
# Education_in_the_Faroe_Islands University_of_the_Faroe_Islands link the Faroe Islands'
# other-empty University_of_the_Faroe_Islands external the Faroe Islands'
# other-internal University_of_the_Faroe_Islands external the Faroe Islands'
# University_of_the_Arctic_members University_of_the_Faroe_Islands link the Faroe Islands'
# Faroe_Islands University_of_the_Faroe_Islands link the Faroe Islands'
# other-search University_of_the_Faroe_Islands external the Faroe Islands'
# Tórshavn University_of_the_Faroe_Islands link the Faroe Islands'
# other-search Beryl_Smalley external Category:20th-century
# other-empty Film_and_Publication_Board external South Africa'
# Motion_picture_content_rating_system Film_and_Publication_Board link South Africa'
# Television_content_rating_system Film_and_Publication_Board link South Africa'
# Computer_Entertainment_Rating_Organization Film_and_Publication_Board link South Africa'
# other-search Film_and_Publication_Board external South Africa'
# Video_game_content_rating_system Film_and_Publication_Board link South Africa'
# other-external Film_and_Publication_Board external South Africa'
# Orange_(colour) Chrome_orange link Inorganic
# List_of_inorganic_pigments Chrome_orange link Inorganic
# other-empty Chrome_orange external Inorganic
# Lead(II)_chromate Chrome_orange link Inorganic
# List_of_alchemical_substances Chrome_orange link Inorganic
# other-search Chrome_orange external Inorganic
# Trombiculidae Chrome_orange link Inorganic
# AFC_Energy Extreme_E link Argentina
# Jenson_Button Extreme_E link Argentina
# Spark_ODYSSEY_21 Extreme_E link Argentina
# Jack_Aitken Extreme_E link Argentina
# 2020–21_Formula_E_World_Championship Extreme_E other Argentina
# Chip_Ganassi_Racing Extreme_E link Argentina
# Valtteri_Bottas Extreme_E link Argentina
# other-empty Extreme_E external Argentina
# Nico_Rosberg Extreme_E link Argentina
# Johan_Kristoffersson Extreme_E link Argentina
# Electric_motorsport Extreme_E link Argentina
# Andretti_Autosport Extreme_E link Argentina
# Catie_Munnings Extreme_E link Argentina
# Cristina_Gutiérrez Extreme_E link Argentina
# 2021_Ocean_X-Prix Extreme_E link Argentina
# Williams_Grand_Prix_Engineering Extreme_E link Argentina
# 2021_IndyCar_Series Extreme_E other Argentina
# Spark_Racing_Technology Extreme_E link Argentina
# 2021_Extreme_E_Championship Extreme_E link Argentina
# Zak_Brown Extreme_E link Argentina
# Fisker_Inc. Extreme_E link Argentina
# other-internal Extreme_E external Argentina
# Claudia_Hürtgen Extreme_E link Argentina
# Jamie_Chadwick Extreme_E link Argentina
# Formula_E Extreme_E link Argentina
# RMS_St_Helena_(1989) Extreme_E link Argentina
# List_of_2017_motorsport_champions Extreme_E other Argentina
# Sara_Price Extreme_E link Argentina
# 2021_Desert_X-Prix Extreme_E link Argentina
# Molly_Taylor Extreme_E link Argentina
# 2021_Formula_One_World_Championship Extreme_E other Argentina
# Jean-Éric_Vergne Extreme_E link Argentina
# United_Autosports Extreme_E link Argentina
# Sébastien_Loeb Extreme_E link Argentina
# Christine_Giampaoli_Zonca Extreme_E link Argentina
# Kyle_LeDuc Extreme_E link Argentina
# Team_Rosberg Extreme_E link Argentina
